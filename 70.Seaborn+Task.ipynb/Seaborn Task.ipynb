# %% [markdown]
# ### 1. Import seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### 2. Import pyplot from matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3. Import pandas for csv file reading

# %%
import pandas as pds

# %% [markdown]
# ### 4. Write the code which allows to show plots in jupiter notebook

# %%
# %matplotlib inline

# %% [markdown]
# ### 5. Create a variable and read data from csv file in it

# %%
data_value = pds.read_csv('german_credit_data.csv')

# %% [markdown]
# ### 6. Show first 10 rows from the dataset

# %%
data_value.head(10)

# %% [markdown]
# ### 7. Try to recreate the plot from image below

# %%
sns.jointplot(x='Age',y='Credit amount',data=data_value)

# %% [markdown]
# ### 8. Try to recreate the plot from image below

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(2,14))
s= sns.displot(data_value['Duration'], color='green',height=4, aspect=1.5)

# %% [markdown]
# ### 9. Try to recreate the plot from image below

# %%
sns.boxplot(data=data_value,x='Housing', y='Age')
# Out:
# <AxesSubplot:xlabel='Housing', ylabel='Age'>

# %% [markdown]
# ### 10. Try to recreate the plot from image below

# %%
sns.swarmplot(data=data_value,x='Housing', y='Age')
# Out:
# C:\Users\home\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\home\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Housing', ylabel='Age'>

# %% [markdown]
# ### 11. Try to recreate the plot from image below

# %%
sns.countplot(data=data_value,x='Sex')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### 12. Try to recreate the plot from image below

# %%
sns.heatmap(data_value.corr(),cmap="Blues_r").set_title('data_value.corr()')
# Out:
# Text(0.5, 1.0, 'data_value.corr()')

# %%
# Out:
# Text(0.5, 1, 'gcd.corr()')

# %% [markdown]
# ### 13. Try to recreate the plot from image below

# %%
data_value.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car

# %%
data_value['Housing'].value_counts()
# Out:
# own     713
# rent    179
# free    108
# Name: Housing, dtype: int64

# %%
data_value[(data_value['Housing']=='free') & (data_value['Credit amount']<=4000)]
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 54           54   57    male    2    free          little         moderate
# 62           62   61    male    3    free          little         moderate
# 68           68   37    male    2    free          little              NaN
# 72           72   51    male    3    free          little           little
# 75           75   66    male    3    free          little           little
# 123         123   63    male    2    free          little             rich
# 133         133   47    male    2    free          little              NaN
# 150         150   42    male    2    free        moderate              NaN
# 187         187   68    male    0    free          little         moderate
# 191         191   34    male    1    free        moderate         moderate
# 198         198   36    male    2    free             NaN         moderate
# ...

# %%
grid = sns.FacetGrid(data=data_value, col= 'Housing')
#grid.set(xlim=4000)
grid.map(plt.hist,'Credit amount')

# %%
grid = sns.FacetGrid(data=data_value, col= 'Housing')
#grid.set(xlim=300)
grid.map(sns.histplot,'Credit amount')
